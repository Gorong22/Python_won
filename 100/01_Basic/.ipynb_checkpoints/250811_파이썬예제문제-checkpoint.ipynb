# %%
#11번가에서 '캠핑용품' 검색 후 -> 인기순 카테고리 클릭, 10페이지 까지 상품명 크롤링

from selenium import webdriver

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

service = Service(ChromeDriverManager().install())
options = Options()

options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent = Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)
url = "https://www.11st.co.kr/page/main/home"
driver.get(url)

#popup_button = driver.find_element(By.CSS_SELECTOR, "button.btn_close")
#time.sleep(2)
#popup_button.click()



search_button = driver.find_element(By.CSS_SELECTOR, "div.c_gnb_search.c_gnb_search_tab input.search_text")
search_button.click()
time.sleep(2)

search_button.send_keys("캠핑용품")
search_button.send_keys(Keys.ENTER)
time.sleep(3)

filter_button = driver.find_element(By.CSS_SELECTOR, "button.btn_icon.select")
time.sleep(1)
filter_button.click()

famus_button = driver.find_element(By.XPATH, ".//ul[@class='dropdown_list']//button[contains(text(), '11번가 인기순')]")
time.sleep(1)
famus_button.click()



for page_num in range(1, 11):
    #print(driver.current_url)
    #driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    #time.sleep(3)

    products = driver.find_elements(By.CSS_SELECTOR, "li.c-search-list__item, div.c-search-list__item")


    for product in products :
        try :
            title_name = product.find_element(By.CSS_SELECTOR, "div.c-card-item__name a, div.c-card-item__name dd")
            price = product.find_element(By.CSS_SELECTOR, "div.c-card-item__price-info span.value")
            print(f"상품명 : {title_name.text}, 가격 : {price.text}")
        
        except Exception as e:
            print(f"상품 정보를 가져오는 중 오류 발생: {e}")
            continue
    #if page_num < 11:
    #num_button = driver.find_elements(By.XPATH, "//li[@class='active']/button")
    #num_button[-1].click()

    #time.sleep(10)
# Out:
# 상품명 : 캠핑 장작 10kg 참나무 땔감 불멍 화목 펜션 바베큐, 가격 : 14,100
# 상품명 : [리베로] 1+1 봄맞이 캠핑의자 모음전, 가격 : 48,500
# 상품명 : 캠프듀아 액화방지 2가지 불조절 요리용 토치, 가격 : 10,350
# 상품명 : 부탄가스 맥스부탄가스220g(28개)1박스, 가격 : 38,400
# 상품명 : 팔팔장작 참나무장작 캠핑 바베큐 미니 사이즈 10kg 15kg, 가격 : 7,780
# 상품명 : [25년] 버전3 선풍기 아이스 18도 여름 에어컨 작업현장 워커스 쿨링조끼 에어쿨링팬 국내제조, 가격 : 99,000
# 상품명 : 고체연료+연료통, 가격 : 6,840
# 상품명 : 베르소냐 캠핑용 스텐 코펠 11종 풀세트 3~4인용 및 다용도 걸이 패키지, 가격 : 41,800
# 상품명 : 카자리코 가스 토치 라이터 터보 화력 캠핑토치 BBQ 요리 손잡이 타입, 가격 : 11,160
# 상품명 : 스피엘 접이식 캠핑 폴딩박스 캠핑용 수납 테이블, 가격 : 28,710
# 상품명 : 매직파이어 오로라 불꽃가루 불멍 30g 10p 대용량 모닥불 무지개 캠핑 감성 숯불, 가격 : 12,060
# 상품명 : [내일도착] 헤스타 100% 국내산 친환경 실리콘 김밥말이 간편 김밥틀 무독성 소풍 나들이 캠핑 조리도구, 가격 : 10,660
# 상품 정보를 가져오는 중 오류 발생: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=138.0.7204.184); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# ...

# %%
#크몽에서 '마케팅' 서비스 필터 조작 후 제목과 가격을 수집하세요.

from selenium import webdriver

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

service = Service(ChromeDriverManager().install())
options = Options()

options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent = Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)
url = "https://kmong.com/?airbridge_referrer=airbridge%3Dtrue%26campaign%3D874874596%26campaign_id%3D874874596%26ad_group%3D76628375026%26ad_group_id%3D76628375026%26ad_creative%3D743779912502%26ad_creative_id%3D743779912502%26term%3D%ED%81%AC%EB%AA%BD%26sub_id%3Dg%26sub_id_1%3D%26sub_id_2%3D%26sub_id_3%3De%26click_id%3DCj0KCQjwzOvEBhDVARIsADHfJJTG_vz6KJl2ZMtUN-w1sUm1XSaUlR-goBNtBArNN4JkN1az6CwZrXcaApAhEALw_wcB%26gclid%3DCj0KCQjwzOvEBhDVARIsADHfJJTG_vz6KJl2ZMtUN-w1sUm1XSaUlR-goBNtBArNN4JkN1az6CwZrXcaApAhEALw_wcB%26ad_type%3Dclick&utm_source=google.adwords&utm_campaign=00_%ED%81%AC%EB%AA%BD%EB%B8%8C%EB%9E%9C%EB%93%9C_pc&utm_medium=Search&utm_term=%ED%81%AC%EB%AA%BD&ad_creative_id=743779912502&ad_group=00_00_%ED%81%AC%EB%AA%BD(%EC%9D%BC%EC%B9%98%EA%B2%80%EC%83%89)&campaign_id=874874596&sub_id=g&sub_id_1=&sub_id_2=&gad_source=1&gad_campaignid=874874596&gbraid=0AAAAADPEzGvtsv2ur5lIlzak0AQM2fV3V&gclid=Cj0KCQjwzOvEBhDVARIsADHfJJTG_vz6KJl2ZMtUN-w1sUm1XSaUlR-goBNtBArNN4JkN1az6CwZrXcaApAhEALw_wcB"
driver.get(url)

search_button = driver.find_element(By.CSS_SELECTOR, "input[data-testid='search-input']")
search_button.click()
time.sleep(2)

search_button.send_keys("마케팅")
search_button.send_keys(Keys.ENTER)
time.sleep(3)

filter_button = driver.find_element(By.XPATH, "//button[.//div[text()='예산']]")
time.sleep(1)
filter_button.click()

price_button = driver.find_element(By.XPATH, "//label[.//span[text()='10~20만원 이하']]")
time.sleep(1)
price_button.click()
time.sleep(3)

confirm_button = driver.find_element(By.XPATH, "//button[./span[text()='적용하기']]")
confirm_button.click()


#for page_num in range(1, 11):
    #print(driver.current_url)
    #driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    #time.sleep(3)

products = driver.find_elements(By.CSS_SELECTOR, "article.css-790i1i.ec40hvj0")


for product in products :
    try :
        title_name = product.find_element(By.XPATH, ".//div[contains(@class,'pt-2')]/span")
        #price = product.find_element(By.CSS_SELECTOR, "div.c-card-item__price-info span.value")
        print(f"상품명 : {title_name.text}")
        
    except Exception as e:
        print(f"상품 정보를 가져오는 중 오류 발생: {e}")
        continue

# %%
#GS샵에서 홈쇼핑 생방송 시간표를 스크롤로 수집하세요.

# %%
#인터파크 티켓에서 공연 카테고리를 클릭해 공연명과 일정 정보를 수집하세요

# %%
#신세계몰에서 ‘식품’ 카테고리의 오늘의 특가 상품명을 수집하세요.

# %%
#페이스북 로그인 후 특정 페이지의 최근 게시글 제목을 수집하세요.

# %%
#카카오맵에서 '맛집' 검색 후 스크롤하여 장소명과 별점을 수집하세요.

# %%
#무신사에 로그인 후 찜한 상품 리스트에서 브랜드명과 가격을 수집하세요.

# %%
#인스타그램에 로그인한 후 특정 계정의 최근 게시물 이미지 URL을 5개 수집

# %%
#Gmail에 로그인한 후 받은편지함에서 최근 이메일 제목 10개를 수집하세요.

# %%
#다나와(*혹은 본인이 자주 방문 및 사용하는 가격비교 사이트) 로그인 후 찜한 상품 리스트를 수집하세요.

# %%
#GS샵(*혹은 본인이 자주 방문 및 구매하는 쇼핑몰) 로그인 후 주문배송조회 페이지의 상품명과 상태를 수집하세요
