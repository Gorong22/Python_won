# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np

# 50행 × 2열 랜덤 데이터
df = pd.DataFrame(np.random.rand(10, 2), columns=["A", "B"])

fig = go.Figure()
fig.add_trace
# Out:
#           A         B
# 0  0.288046  0.676760
# 1  0.874981  0.362904
# 2  0.170278  0.333054
# 3  0.864542  0.998826
# 4  0.970358  0.189097
# 5  0.886837  0.976209
# 6  0.907301  0.131106
# 7  0.922505  0.278601
# 8  0.994433  0.685984
# 9  0.049024  0.624519

# %%
import numpy as np

test = np.random.rand(2, 2)
test

# pandas > Series (1차원 배열의 데이터) / DataFrame(2차원 배열의 데이터 )
# Out:
# array([[0.49716609, 0.64114973],
#        [0.89500098, 0.73582338]])
