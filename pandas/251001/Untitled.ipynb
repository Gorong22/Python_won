# %%
import pandas as pd 

df = pd.DataFrame({
    "A" : [1,2,3,4,5,6],
    "B" : [1,2,3,4,5,100],
})

df
# Out:
#    A    B
# 0  1    1
# 1  2    2
# 2  3    3
# 3  4    4
# 4  5    5
# 5  6  100

# %%
df.describe()
# Out:
#               A           B
# count  6.000000    6.000000
# mean   3.500000   19.166667
# std    1.870829   39.625329
# min    1.000000    1.000000
# 25%    2.250000    2.250000
# 50%    3.500000    3.500000
# 75%    4.750000    4.750000
# max    6.000000  100.000000

# %%
import plotly.express as px 

fig = px.box(
    df,
    y=["A", "B"],
    title="Plotly Express : Box plot"
)

fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()

# %%
import numpy as np
import pandas as pd 

df = pd.DataFrame(np.random.rand(100000,1), columns=["A"])

df.head()
# Out:
#           A
# 0  0.881806
# 1  0.742051
# 2  0.800483
# 3  0.009150
# 4  0.157374

# %%
import plotly.express as px 

fig = px.histogram(
    df,
    x=["A"],
    nbins=50
)

fig.show()

# %%
import pandas as pd 

data = {
    "year" : ["2017", "2017", "2019", "2020", "2021", "2021"],
    "grade" : ["C", "C", "B", "A", "B", "E"]
}

df = pd.DataFrame(data)

# %%
df["year"].value_counts()
# Out:
# year
# 2017    2
# 2021    2
# 2019    1
# 2020    1
# Name: count, dtype: int64

# %%
df["year"].size
# Out:
# 6

# %%
df["year"].unique()
# Out:
# array(['2017', '2019', '2020', '2021'], dtype=object)

# %%
import plotly.express as px 



fig = px.bar(
    x=df.index,
    y=df1["year"]
)

# %%
import plotly.express as px

fig = px.pie(
    values=df1["year"]
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 import plotly.express as px
#       3 fig = px.pie(
# ----> 4     values=df1["year"]
#       5 )
#       7 fig.show()
#
# NameError: name 'df1' is not defined

# %%
import graph_objects as go

fig_go_line = go.Figure()

fig_go_line.add_trace(
    go.Scatter(
        x=df.index,
        y=df["count"],
        mode="lines+markers",
        name="Count",
        showlegend=True
    )
)

fig_go_line.update_layout(
    title="Time Series Line Plot",
    xaxis_title="date",
    yaxis_title="Count"
)

fig_go_line.update_xaxes(
    tickmode="array",
    tickval=df.index
)

fig_go_line
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import graph_objects as go
#       3 fig_go_line = go.Figure()
#       5 fig_go_line.add_trace(
#       6     go.Scatter(
#       7         x=df.index,
#    (...)
#      12     )
#      13 )
#
# ModuleNotFoundError: No module named 'graph_objects'
