# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /opt/anaconda3/lib/python3.13/site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (1.18.2)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (72.1.0)
# Requirement already satisfied: six>=1.10 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (4.3.7)
# Requirement already satisfied: typing_extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (4.14.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.13/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/anaconda3/lib/python3.13/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (2025.6.15)

# %%
import os

os.environ["KAGGLE_USERNAME"]
os.environ["KAGGLE_AOI_TOKEN"] = "KGAT_7c25aba2c3f33e89a612741068b140f4"
# Out:
# Could not find kaggle.json. Make sure it's located in /Users/mac/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !kaggle --version
# Out:
# Kaggle API 1.8.2

# %%
import pandas as pd

train = pd.read_csv("titanic/train.csv")
test = pd.read_csv("titanic/test.csv")

# %%
test.shape
# Out:
# (418, 11)

# %%
train[(train["Age"] >= 1) & (train["Age"] <=2)]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# 16            17         0       3               Rice, Master. Eugene    male
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
# 164          165         0       3       Panula, Master. Eino Viljami    male
# 172          173         1       3       Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2          Becker, Master. Richard F    male
# 205          206         0       3         Strom, Miss. Telma Matilda  female
# 297          298         0       1       Allison, Miss. Helen Loraine  female
# 340          341         1       2     Navratil, Master. Edmond Roger    male
# 381          382         1       3        Nakid, Miss. Maria ("Mary")  female
# 386          387         0       3    Goodwin, Master. Sidney Leonard    male
# 479          480         1       3           Hirvonen, Miss. Hildur E  female
# 530          531         1       2           Quick, Miss. Phyllis May  female
# 642          643         0       3      Skoog, Miss. Margit Elizabeth  female
# 788          789         1       3         Dean, Master. Bertram Vere    male
# 824          825         0       3       Panula, Master. Urho Abraham    male
# 827          828         1       2              Mallet, Master. Andre    male
#
#      Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# 7    2.0      3      1           349909   21.0750      NaN        S
# 16   2.0      4      1           382652   29.1250      NaN        Q
# 119  2.0      4      2           347082   31.2750      NaN        S
# 164  1.0      4      1          3101295   39.6875      NaN        S
# 172  1.0      1      1           347742   11.1333      NaN        S
# 183  1.0      2      1           230136   39.0000       F4        S
# 205  2.0      0      1           347054   10.4625       G6        S
# 297  2.0      1      2           113781  151.5500  C22 C26        S
# 340  2.0      1      1           230080   26.0000       F2        S
# 381  1.0      0      2             2653   15.7417      NaN        C
# 386  1.0      5      2          CA 2144   46.9000      NaN        S
# 479  2.0      0      1          3101298   12.2875      NaN        S
# 530  2.0      1      1            26360   26.0000      NaN        S
# 642  2.0      3      2           347088   27.9000      NaN        S
# 788  1.0      1      2        C.A. 2315   20.5750      NaN        S
# 824  2.0      4      1          3101295   39.6875      NaN        S
# 827  1.0      0      2  S.C./PARIS 2079   37.0042      NaN        C

# %%
import plotly.express as px 

corr_matrix = train.corr(numeric_only=True)

fig_px = px.imshow(
    corr_matrix,
    text_auto=True,
    aspect="auto",
    title="Heatmap (Plotly Express)"
    color_continuous_scale="Blues"
)

fig_px.show()
# Out:
#   Cell In[24], line 9
#     title="Heatmap (Plotly Express)"
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
