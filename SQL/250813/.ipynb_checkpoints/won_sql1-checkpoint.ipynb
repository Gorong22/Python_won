# %%
import pymysql

db = pymysql.connect(  # ← 여기서 변수 db 생성
    host="localhost",
    port=3306,
    user="root",
    password="Wonsil929621!@#",
    db="ecommerce_v1",
    charset="utf8"
)

print(db)  # 이제 db 변수 출력 가능

# %%
ecommercev1 = db.cursor()

# %%
ecommercev1

# %%
sql = """ 
    create table product(
        product_code varchar(20) not null,
        title varchar(200) not null,
        ori_price int,
        discount_price int,
        discount_percent int,
        delivery varchar(2)
    ); 

"""

# %%
sql
# Out:
# ' \n    create table product(\n        product_code varchar(20) not null,\n        title varchar(200) not null,\n        ori_price int,\n        discount_price int,\n        discount_percent int,\n        delivery varcahr(2)\n    ); \n\n'

# %%
ecommercev1.execute(sql)
# Out:
# 0

# %%
db.commit()

# %%
db.close()

# %%
import pymysql

db = pymysql.connect(  # ← 여기서 변수 db 생성
    host="localhost",
    port=3306,
    user="root",
    password="Wonsil929621!@#",
    db="ecommerce_v1",
    charset="utf8"
)

print(db)  # 이제 db 변수 출력 가능

# %%
cursor = db.cursor()

# %%
for index in range(10) :
    product_code = 215673150 + index + 1
    SQL = f""" 
        INSERT into product Values(
            '{product_code}',
            '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
            23000,
            6900,
            70,
            'F'
            
        );
    
    """
    cursor.execute(SQL)
# Out:
#
#         INSERT into product Values(
#             '215673151',
#             '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
#             23000,
#             6900,
#             70,
#             'F'
#
#         );
#
#
#
#         INSERT into product Values(
#             '215673152',
#             '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
#             23000,
#             6900,
#             70,
#             'F'
#
#         );
#
#
#
#         INSERT into product Values(
#             '215673153',
#             '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
#             23000,
#             6900,
#             70,
#             'F'
#
#         );
#
#
#
#         INSERT into product Values(
#             '215673154',
#             '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
#             23000,
#             6900,
#             70,
#             'F'
#
#         );
#
#
#
#         INSERT into product Values(
#             '215673155',
#             '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔',
#             23000,
# ...

# %%
db.commit()

# %%
db.close()

# %%
SQL = "select * from product"
cursor.execute(SQL)
row =cursor.fetchone()
print(row)
# Out:
# ('215673150', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')

# %%
row =cursor.fetchone()
print(row)
# Out:
# ('215673151', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')

# %%
rows = cursor.fetchmany(2)
print(rows)
# Out:
# (('215673152', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'), ('215673153', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'))

# %%
rows_all = cursor.fetchall()
for row in rows_all :
    print(row)
# Out:
# ('215673154', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673155', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673156', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673157', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673158', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673159', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673160', '스위트바니 여름신상 5900 ~ 롱원피스/티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')

# %%
SQL =  """ 
    update product set 
        title = "썸머 가디건 코디전",
        ori_price = 33000,
        discount_price = 9900,
        discount_percent = 70
    where product_code = 215673160;
"""

# %%
cursor.execute(SQL)
# Out:
# 1

# %%
db.commit()

# %%
SQL = """Delete From product where product_code = '215673160';"""
print(SQL)
# Out:
# Delete From product where product_code = '215673160';

# %%
cursor.execute(SQL)
# Out:
# 1

# %%
db.commit()
