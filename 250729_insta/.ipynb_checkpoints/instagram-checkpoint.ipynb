# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

#서비스와 옵션을 웹드라이브에 넣어야함 웹드라이브 매니저 필요함
from webdriver_manager.chrome import ChromeDriverManager
import pickle

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang-ko_KR")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

url = "https://www.instagram.com/accounts/login/#"
driver.get(url)
print("수동으로 인증 시작")
time.sleep(60)

with open("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

#서비스와 옵션을 웹드라이브에 넣어야함 웹드라이브 매니저 필요함
from webdriver_manager.chrome import ChromeDriverManager
import pickle

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang-ko_KR")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com")
with open("instagram_cookies.pkl", "rb") as f :
    cookies = pickle.load(f)

for cookie in cookies :
    driver.add_cookie(cookie) 

driver.refresh()
time.sleep(5)

try :
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)

except :
    pass

keyword = "나이키"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url": url, "caption": caption})
        
    except Exception as e :
        print(f"캡션 추출 실패 : {url} | 에러 : {e}")
        continue
        
driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DCy0AkIIuGC/
# Photo by 런던하이 I 쉽게꾸리는 살림과 식탁🏠 on November 25, 2024. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DMMPzOGSnEG/
# Photo shared by MUSINSA 무신사 on July 16, 2025 tagging @nikeseoul. 사람 1명 및 문구: 'BEu EVENT 감다살 나이키 드릴게 들어와보셔'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DHNfnTDTCNa/
# Photo by 크로켓 on March 15, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DLXJOVQJ95P/
# Photo by 수영선수 박한별 Park han byeol on June 26, 2025. 사람 1명, 코끼리, 수건, 사롱, 야외 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/C2b-IlYJueG/
# Photo by 크로켓 on January 23, 2024. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DMoiHuOTbrO/
# Photo by 전시회를즐기다 in 성수동 with @nikeseoul, and @enjoyexhibition. 사람 3명, 축구하는 사람들, 테니스하는 사람들, 공, 비치볼, 스포츠 장비 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMp3DHTy6ZY/
# Photo shared by 패션 & 스타일 (Fashion & Style) on July 28, 2025 tagging @katarinabluu. 사람 1명 및 문구: 'A 天 지모 추가 공개 시작됨 카리나이키'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DH0cHxmzx3e/
# Photo by 크로켓 on March 30, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DJyM2NxJp_6/
# Photo shared by 우아 on May 17, 2025 tagging @nikerunning, @nikeseoul, and @photo_ok_bro. 사람 1명 이상 및 야외의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DK_DfDISI8y/
# Photo shared by 옵스큐어 페이퍼 Obscure.Paper on June 16, 2025 tagging @nike. 사람 1명, 신발류 및 문구: '地料 시원한 컬러감으로 눈길을 사로잡는 나이키 필드 제너럴 82'의 이미지일 수 있음.
# ============================================================
